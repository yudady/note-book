# %%
import cv2
import numpy as np

from matplotlib import pyplot as plt

# %%
img = cv2.imread("angel.jpg")


gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
#img2 = gray[:,:,::-1]
plt.imshow(gray)

# %%
img2 = cv2.imread("angel.jpg",1)
plt.imshow(img2)
